# %%
# System imports
import os
import sys
from pprint import pprint as pp
from time import time

# External imports
import matplotlib.pyplot as plt
import matplotlib.colors
import numpy as np
import pandas as pd
import seaborn as sns
import random
import torch
import pickle

# %%
print("PyTorch version:",print(torch.__version__),", CUDA version:", torch.version.cuda)
# Out:
# 2.1.0+cu121
# PyTorch version: None , CUDA version: 12.1

# %%
from torch_geometric.data import Data
from torch_geometric.data import DataLoader
import torch.nn as nn
from torch_scatter import scatter_add
import torch.nn.functional as F

import ipywidgets as widgets
from ipywidgets import interact, interact_manual
from IPython.display import clear_output
from IPython.display import HTML, display

# Get rid of RuntimeWarnings, gross
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
# disable interactive plots
# %matplotlib inline

# enable interactive plots
# %matplotlib notebook

# %%
def train(model, train_loader, optimizer):
    correct = 0
    total = 0
    total_loss = 0
    for batch in train_loader:
        optimizer.zero_grad()
        data = batch.to(device)
        pred = model(data)
        loss = F.binary_cross_entropy_with_logits(pred.float(), data.y.float(), pos_weight=torch.tensor(weight))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        correct += ((pred > 0.5) == (data.y > 0.5)).sum().item()
        total += len(pred)
    acc = correct/total
    return acc, total_loss

def evaluate(model, test_loader):
    correct = 0
    total = 0
    total_loss = 0
    for batch in test_loader:
        data = batch.to(device)
        pred = model(data)
        loss = F.binary_cross_entropy_with_logits(pred.float(), data.y.float(), pos_weight=torch.tensor(weight))
        total_loss += loss.item()
        correct += ((pred > 0.5) == (data.y > 0.5)).sum().item()
        total += len(pred)
    acc = correct/total
    return acc, total_loss

# %%
def make_mlp(input_size, sizes,
             hidden_activation='ReLU',
             output_activation='ReLU',
             layer_norm=False):
    """Construct an MLP with specified fully-connected layers."""
    hidden_activation = getattr(nn, hidden_activation)
    if output_activation is not None:
        output_activation = getattr(nn, output_activation)
    layers = []
    n_layers = len(sizes)
    sizes = [input_size] + sizes
    # Hidden layers
    for i in range(n_layers-1):
        layers.append(nn.Linear(sizes[i], sizes[i+1]))
        if layer_norm:
            layers.append(nn.LayerNorm(sizes[i+1]))
        layers.append(hidden_activation())
    # Final layer
    layers.append(nn.Linear(sizes[-2], sizes[-1]))
    if output_activation is not None:
        if layer_norm:
            layers.append(nn.LayerNorm(sizes[-1]))
        layers.append(output_activation())
    return nn.Sequential(*layers)

class MPNN_Network(nn.Module):
    """
    A message-passing graph network which takes a graph with:
    - bi-directional edges
    - node features, no edge features

    and applies the following modules:
    - a graph encoder (no message passing)
    - recurrent edge and node networks
    - an edge classifier
    """

    def __init__(self, input_dim, hidden_node_dim, hidden_edge_dim, in_layers, node_layers, edge_layers,
                 n_graph_iters=1, layer_norm=True):
        super(MPNN_Network, self).__init__()
        self.n_graph_iters = n_graph_iters

        # The node encoder transforms input node features to the hidden space
        self.node_encoder = make_mlp(input_dim, [hidden_node_dim]*in_layers)

        # The edge network computes new edge features from connected nodes
        self.edge_network = make_mlp(2*hidden_node_dim,
                                     [hidden_edge_dim]*edge_layers,
                                     layer_norm=layer_norm)

        # The node network computes new node features
        self.node_network = make_mlp(hidden_node_dim + hidden_edge_dim,
                                     [hidden_node_dim]*node_layers,
                                     layer_norm=layer_norm)

        # The edge classifier computes final edge scores
        self.edge_classifier = make_mlp(2*hidden_node_dim,
                                        [hidden_edge_dim, 1],
                                        output_activation=None)

    def forward(self, data):
        # Make every edge bi-directional
        send_idx = torch.cat([data.edge_index[0], data.edge_index[1]], dim=0)
        recv_idx = torch.cat([data.edge_index[1], data.edge_index[0]], dim=0)

        # Encode the graph features into the hidden space
        x = self.node_encoder(data.x)

        # Loop over graph iterations
        for i in range(self.n_graph_iters):

            # Previous hidden state
            x0 = x

            # Compute new edge features
            edge_inputs = torch.cat([x[send_idx], x[recv_idx]], dim=1)
            e = self.edge_network(edge_inputs)

            # Sum edge features coming into each node
            aggr_messages = scatter_add(e, recv_idx, dim=0, dim_size=x.shape[0])

            # Compute new node features
            node_inputs = torch.cat([x, aggr_messages], dim=1)
            x = self.node_network(node_inputs)

            # Residual connection
            x = x + x0

        # Compute final edge scores; use original edge directions only
        start_idx, end_idx = data.edge_index
        clf_inputs = torch.cat([x[start_idx], x[end_idx]], dim=1)
        return self.edge_classifier(clf_inputs).squeeze(-1)

# %%
position_scale = 50.
feature_scale = 200.

# %%
# hitPos, hitType, layerZ, layerIndex, trackID

# event_file_name = '/home/jupyter-dmizera/GNN_3D/hitFile_small.pickle'
# mc_file_name = '/home/jupyter-dmizera/GNN_3D/MCtrackFile_small.pickle'

# event_file_name = '/home/jupyter-dmizera/GNN_3D/hitFile_medium.pickle'
# mc_file_name = '/home/jupyter-dmizera/GNN_3D/MCtrackFile_medium.pickle'

event_file_name = '/home/jupyter-dmizera/GNN_3D/hitFile_big.pickle'
mc_file_name = '/home/jupyter-dmizera/GNN_3D/MCtrackFile_big.pickle'

# %%
def readMuonE():

    with open(event_file_name, mode='rb') as events_file, open(mc_file_name, mode='rb') as mc_file:
        events = pickle.load(events_file)
        mc = pickle.load(mc_file)

        layers_zs =  [832.0, 843.7, 1141.0, 1146.0, 1252.7, 1266.0, 1467.4, 1479.6, 1960.0, 1973.0]
        num_layers = len(layers_zs)
        
        data_GNN_out = []
        data_tracks_out = [] # for saving indexes of hits of track for every event
        data_mc_out = []
        
        for event_index, event in enumerate(events):
            
            X = None
            track_hits = {'track_1': set(), 'track_2': set()} # for saving indexes of hits that belong to track 1 or 2
            
            for hit_index, hit in enumerate(event):
                if hit_index == 0:
                    X = np.array([[hit[0]*position_scale, # position
                                   hit[2], # z
                                   hit[3], # layer index
                                   hit[4]]]) # trackID
                    
                else:
                    X = np.append(X, np.array([[hit[0]*position_scale, # position
                                                hit[2], # z
                                                hit[3], # layer index
                                                hit[4]]]), axis=0) # trackID
                    
                # save hit index to track
                track_hits['track_1'].add(hit_index) if int(hit[4]) == 1 else track_hits['track_2'].add(hit_index)
                    
            e = []
            for layer in np.arange(num_layers - 1):
                for i in np.argwhere(X[:, 1] == layers_zs[layer]):
                    for j in np.argwhere(X[:, 1] == layers_zs[layer + 1]):
                        e.append([i, j])
            e = np.array(e).T.squeeze()

            try:
                y = np.array([int(i[3] == j[3]) for i,j in zip(X[e[0]], X[e[1]])])

            except:
                # handle no edges created
                continue

            X = np.array([X[:,1], X[:,0]]).T / feature_scale # z, position
            
            data_event = Data(x = torch.from_numpy(X).float(),
                             edge_index = torch.from_numpy(e),
                             y = torch.from_numpy(y),
                             pid = torch.from_numpy(X[:,1]))

            data_GNN_out.append(data_event)
            data_tracks_out.append(track_hits)
            data_mc_out.append(mc[event_index])
        
        return data_GNN_out, data_tracks_out, data_mc_out

# %%
def plot_2D_graph(event, ylim=0.):

#     print(event)
#     print(event.x)
#     print(event.edge_index)
#     print(event.y)
#     print(event.pid)

    plt.figure(figsize=(10,5))
    x, y = event.x[:,0].numpy(), event.x[:,1].numpy()
    e = event.edge_index.numpy()
    
    plt.plot([x[e[0,:]], x[e[1,:]]], [y[e[0,:]], y[e[1,:]]], c='b')

    plt.scatter(x, y, c='k')
    
    if (ylim!=0):
        plt.ylim(-ylim, ylim)
    else:
        diff = 0.1*(max(y)-min(y))
        plt.ylim(min(y)-diff, max(y)+diff)

# %%
# read data and prepare for training
data = list(zip(*readMuonE()))
random.shuffle(data)
data_GNN, data_tracks, data_mc = zip(*data)

# split data into training and test datasets
split_index = int(0.8 * len(data_GNN))
train_dataset = data_GNN[:split_index]
test_dataset = data_GNN[split_index:]
data_tracks = data_tracks[split_index:]
data_mc = data_mc[split_index:]

train_loader = DataLoader(train_dataset, batch_size=100, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

print("Fake / True = ", (len(train_dataset[0].y) - train_dataset[0].y.sum().item()) / train_dataset[0].y.sum().item())
print("Training dataset (events): ", len(train_dataset))
print("Test dataset (events): ", len(test_dataset))

# display few events
for k in range(10):
    plot_2D_graph(train_loader.dataset[k])
# Out:
# Fake / True =  1.0
# Training dataset (events):  79941
# Test dataset (events):  19986
# /home/jupyter-dmizera/.local/lib/python3.9/site-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">

# %%
t_loss_v = []
t_acc_v = []
v_loss_v = []
v_acc_v = []
ep = 0

# %%
weight = 2

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
m_configs = {"input_dim": 2, "hidden_node_dim": 128, "hidden_edge_dim": 256, "in_layers": 2, "node_layers": 2, "edge_layers": 2, "n_graph_iters": 10, "layer_norm": True}
model = MPNN_Network(**m_configs).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-3, amsgrad=True)

# %%
EPOCHS = 500

start_time = time()
epoch_times = []

for epoch in range(EPOCHS):
    ep += 1
    
    epoch_start_time = time()
    
    model.train()
    acc, total_loss = train(model, train_loader, optimizer)
    t_loss_v.append(total_loss)
    t_acc_v.append(acc)

    model.eval()
    acc, total_loss = evaluate(model, test_loader)
    v_loss_v.append(total_loss)
    v_acc_v.append(acc)

    epoch_end_time = time()
    epoch_times.append(epoch_end_time - epoch_start_time)
    avg_epoch_time = sum(epoch_times) / len(epoch_times)
    remaining_time = avg_epoch_time * (EPOCHS - (epoch + 1))
    remaining_minutes, remaining_seconds = divmod(remaining_time, 60)
    
    print('Epoch: {}, Accuracy: {:.4f}, Time: {:.2f}s, Avg. Time/Epoch: {:.2f}s, Remaining Time: {:.0f}min:{:.0f}s'.format(
        ep, acc, epoch_end_time - epoch_start_time, avg_epoch_time, remaining_minutes, remaining_seconds))
    
end_time = time()
total_training_time = end_time - start_time
total_minutes, total_seconds = divmod(total_training_time, 60)
print('Total Training Time: {:.0f}min:{:.0f}s'.format(total_minutes, total_seconds))
# Out:
# Epoch: 1, Accuracy: 0.9689, Time: 15.15s, Avg. Time/Epoch: 15.15s, Remaining Time: 125min:60s
# Epoch: 2, Accuracy: 0.9715, Time: 14.98s, Avg. Time/Epoch: 15.07s, Remaining Time: 125min:3s
# Epoch: 3, Accuracy: 0.9652, Time: 15.11s, Avg. Time/Epoch: 15.08s, Remaining Time: 124min:56s
# Epoch: 4, Accuracy: 0.9763, Time: 15.22s, Avg. Time/Epoch: 15.12s, Remaining Time: 124min:57s
# Epoch: 5, Accuracy: 0.9748, Time: 15.25s, Avg. Time/Epoch: 15.14s, Remaining Time: 124min:56s
# Epoch: 6, Accuracy: 0.9763, Time: 15.29s, Avg. Time/Epoch: 15.17s, Remaining Time: 124min:53s
# Epoch: 7, Accuracy: 0.9778, Time: 15.28s, Avg. Time/Epoch: 15.18s, Remaining Time: 124min:46s
# Epoch: 8, Accuracy: 0.9774, Time: 15.31s, Avg. Time/Epoch: 15.20s, Remaining Time: 124min:38s
# Epoch: 9, Accuracy: 0.9777, Time: 15.31s, Avg. Time/Epoch: 15.21s, Remaining Time: 124min:29s
# Epoch: 10, Accuracy: 0.9741, Time: 15.31s, Avg. Time/Epoch: 15.22s, Remaining Time: 124min:18s
# Epoch: 11, Accuracy: 0.9779, Time: 15.27s, Avg. Time/Epoch: 15.23s, Remaining Time: 124min:6s
# Epoch: 12, Accuracy: 0.9794, Time: 15.28s, Avg. Time/Epoch: 15.23s, Remaining Time: 123min:53s
# Epoch: 13, Accuracy: 0.9767, Time: 15.27s, Avg. Time/Epoch: 15.23s, Remaining Time: 123min:39s
# Epoch: 14, Accuracy: 0.9801, Time: 15.28s, Avg. Time/Epoch: 15.24s, Remaining Time: 123min:25s
# Epoch: 15, Accuracy: 0.9788, Time: 15.27s, Avg. Time/Epoch: 15.24s, Remaining Time: 123min:11s
# Epoch: 16, Accuracy: 0.9789, Time: 15.28s, Avg. Time/Epoch: 15.24s, Remaining Time: 122min:57s
# Epoch: 17, Accuracy: 0.9780, Time: 15.27s, Avg. Time/Epoch: 15.24s, Remaining Time: 122min:43s
# Epoch: 18, Accuracy: 0.9782, Time: 15.27s, Avg. Time/Epoch: 15.24s, Remaining Time: 122min:28s
# Epoch: 19, Accuracy: 0.9769, Time: 15.24s, Avg. Time/Epoch: 15.24s, Remaining Time: 122min:13s
# Epoch: 20, Accuracy: 0.9722, Time: 15.24s, Avg. Time/Epoch: 15.24s, Remaining Time: 121min:57s
# Epoch: 21, Accuracy: 0.9767, Time: 15.25s, Avg. Time/Epoch: 15.24s, Remaining Time: 121min:42s
# Epoch: 22, Accuracy: 0.9801, Time: 15.26s, Avg. Time/Epoch: 15.25s, Remaining Time: 121min:27s
# Epoch: 23, Accuracy: 0.9788, Time: 15.24s, Avg. Time/Epoch: 15.25s, Remaining Time: 121min:12s
# Epoch: 24, Accuracy: 0.9807, Time: 15.25s, Avg. Time/Epoch: 15.25s, Remaining Time: 120min:57s
# Epoch: 25, Accuracy: 0.9792, Time: 15.24s, Avg. Time/Epoch: 15.24s, Remaining Time: 120min:41s
# Epoch: 26, Accuracy: 0.9751, Time: 15.26s, Avg. Time/Epoch: 15.25s, Remaining Time: 120min:26s
# Epoch: 27, Accuracy: 0.9772, Time: 15.23s, Avg. Time/Epoch: 15.24s, Remaining Time: 120min:11s
# Epoch: 28, Accuracy: 0.9771, Time: 15.23s, Avg. Time/Epoch: 15.24s, Remaining Time: 119min:55s
# Epoch: 29, Accuracy: 0.9788, Time: 15.28s, Avg. Time/Epoch: 15.25s, Remaining Time: 119min:41s
# Epoch: 30, Accuracy: 0.9782, Time: 15.21s, Avg. Time/Epoch: 15.24s, Remaining Time: 119min:25s
# Epoch: 31, Accuracy: 0.9757, Time: 15.19s, Avg. Time/Epoch: 15.24s, Remaining Time: 119min:9s
# Epoch: 32, Accuracy: 0.9768, Time: 15.19s, Avg. Time/Epoch: 15.24s, Remaining Time: 118min:53s
# Epoch: 33, Accuracy: 0.9772, Time: 15.20s, Avg. Time/Epoch: 15.24s, Remaining Time: 118min:37s
# Epoch: 34, Accuracy: 0.9785, Time: 15.21s, Avg. Time/Epoch: 15.24s, Remaining Time: 118min:21s
# Epoch: 35, Accuracy: 0.9798, Time: 15.21s, Avg. Time/Epoch: 15.24s, Remaining Time: 118min:6s
# Epoch: 36, Accuracy: 0.9816, Time: 15.21s, Avg. Time/Epoch: 15.24s, Remaining Time: 117min:50s
# Epoch: 37, Accuracy: 0.9797, Time: 15.19s, Avg. Time/Epoch: 15.24s, Remaining Time: 117min:34s
# Epoch: 38, Accuracy: 0.9768, Time: 15.21s, Avg. Time/Epoch: 15.23s, Remaining Time: 117min:19s
# Epoch: 39, Accuracy: 0.9818, Time: 15.19s, Avg. Time/Epoch: 15.23s, Remaining Time: 117min:3s
# Epoch: 40, Accuracy: 0.9827, Time: 15.28s, Avg. Time/Epoch: 15.23s, Remaining Time: 116min:48s
# Epoch: 41, Accuracy: 0.9816, Time: 15.26s, Avg. Time/Epoch: 15.24s, Remaining Time: 116min:33s
# Epoch: 42, Accuracy: 0.9825, Time: 15.23s, Avg. Time/Epoch: 15.24s, Remaining Time: 116min:18s
# Epoch: 43, Accuracy: 0.9749, Time: 15.21s, Avg. Time/Epoch: 15.23s, Remaining Time: 116min:2s
# Epoch: 44, Accuracy: 0.9794, Time: 15.22s, Avg. Time/Epoch: 15.23s, Remaining Time: 115min:47s
# Epoch: 45, Accuracy: 0.9838, Time: 15.22s, Avg. Time/Epoch: 15.23s, Remaining Time: 115min:31s
# Epoch: 46, Accuracy: 0.9840, Time: 15.21s, Avg. Time/Epoch: 15.23s, Remaining Time: 115min:16s
# Epoch: 47, Accuracy: 0.9818, Time: 15.24s, Avg. Time/Epoch: 15.23s, Remaining Time: 115min:1s
# Epoch: 48, Accuracy: 0.9834, Time: 15.20s, Avg. Time/Epoch: 15.23s, Remaining Time: 114min:45s
# Epoch: 49, Accuracy: 0.9828, Time: 15.19s, Avg. Time/Epoch: 15.23s, Remaining Time: 114min:30s
# Epoch: 50, Accuracy: 0.9841, Time: 15.19s, Avg. Time/Epoch: 15.23s, Remaining Time: 114min:14s
# Epoch: 51, Accuracy: 0.9855, Time: 15.18s, Avg. Time/Epoch: 15.23s, Remaining Time: 113min:58s
# Epoch: 52, Accuracy: 0.9845, Time: 15.19s, Avg. Time/Epoch: 15.23s, Remaining Time: 113min:43s
# Epoch: 53, Accuracy: 0.9819, Time: 15.19s, Avg. Time/Epoch: 15.23s, Remaining Time: 113min:27s
# Epoch: 54, Accuracy: 0.9842, Time: 15.19s, Avg. Time/Epoch: 15.23s, Remaining Time: 113min:12s
# Epoch: 55, Accuracy: 0.9839, Time: 15.18s, Avg. Time/Epoch: 15.23s, Remaining Time: 112min:56s
# Epoch: 56, Accuracy: 0.9841, Time: 15.19s, Avg. Time/Epoch: 15.23s, Remaining Time: 112min:41s
# Epoch: 57, Accuracy: 0.9829, Time: 15.18s, Avg. Time/Epoch: 15.23s, Remaining Time: 112min:25s
# Epoch: 58, Accuracy: 0.9847, Time: 15.18s, Avg. Time/Epoch: 15.23s, Remaining Time: 112min:9s
# Epoch: 59, Accuracy: 0.9845, Time: 15.18s, Avg. Time/Epoch: 15.22s, Remaining Time: 111min:54s
# Epoch: 60, Accuracy: 0.9856, Time: 15.18s, Avg. Time/Epoch: 15.22s, Remaining Time: 111min:38s
# Epoch: 61, Accuracy: 0.9866, Time: 15.19s, Avg. Time/Epoch: 15.22s, Remaining Time: 111min:23s
# Epoch: 62, Accuracy: 0.9842, Time: 15.19s, Avg. Time/Epoch: 15.22s, Remaining Time: 111min:7s
# Epoch: 63, Accuracy: 0.9861, Time: 15.18s, Avg. Time/Epoch: 15.22s, Remaining Time: 110min:52s
# Epoch: 64, Accuracy: 0.9881, Time: 15.19s, Avg. Time/Epoch: 15.22s, Remaining Time: 110min:36s
# Epoch: 65, Accuracy: 0.9869, Time: 15.19s, Avg. Time/Epoch: 15.22s, Remaining Time: 110min:21s
# Epoch: 66, Accuracy: 0.9880, Time: 15.20s, Avg. Time/Epoch: 15.22s, Remaining Time: 110min:6s
# Epoch: 67, Accuracy: 0.9868, Time: 15.19s, Avg. Time/Epoch: 15.22s, Remaining Time: 109min:50s
# Epoch: 68, Accuracy: 0.9875, Time: 15.19s, Avg. Time/Epoch: 15.22s, Remaining Time: 109min:35s
# Epoch: 69, Accuracy: 0.9809, Time: 15.19s, Avg. Time/Epoch: 15.22s, Remaining Time: 109min:20s
# Epoch: 70, Accuracy: 0.9844, Time: 15.21s, Avg. Time/Epoch: 15.22s, Remaining Time: 109min:4s
# Epoch: 71, Accuracy: 0.9851, Time: 15.20s, Avg. Time/Epoch: 15.22s, Remaining Time: 108min:49s
# Epoch: 72, Accuracy: 0.9874, Time: 15.19s, Avg. Time/Epoch: 15.22s, Remaining Time: 108min:33s
# Epoch: 73, Accuracy: 0.9838, Time: 15.18s, Avg. Time/Epoch: 15.22s, Remaining Time: 108min:18s
# Epoch: 74, Accuracy: 0.9859, Time: 15.20s, Avg. Time/Epoch: 15.22s, Remaining Time: 108min:3s
# Epoch: 75, Accuracy: 0.9850, Time: 15.17s, Avg. Time/Epoch: 15.22s, Remaining Time: 107min:47s
# Epoch: 76, Accuracy: 0.9771, Time: 15.19s, Avg. Time/Epoch: 15.22s, Remaining Time: 107min:32s
# Epoch: 77, Accuracy: 0.9814, Time: 15.17s, Avg. Time/Epoch: 15.22s, Remaining Time: 107min:16s
# Epoch: 78, Accuracy: 0.9847, Time: 15.19s, Avg. Time/Epoch: 15.22s, Remaining Time: 107min:1s
# Epoch: 79, Accuracy: 0.9856, Time: 15.16s, Avg. Time/Epoch: 15.22s, Remaining Time: 106min:46s
# Epoch: 80, Accuracy: 0.9866, Time: 15.18s, Avg. Time/Epoch: 15.21s, Remaining Time: 106min:30s
# Epoch: 81, Accuracy: 0.9839, Time: 15.17s, Avg. Time/Epoch: 15.21s, Remaining Time: 106min:15s
# Epoch: 82, Accuracy: 0.9881, Time: 15.18s, Avg. Time/Epoch: 15.21s, Remaining Time: 105min:59s
# Epoch: 83, Accuracy: 0.9888, Time: 15.17s, Avg. Time/Epoch: 15.21s, Remaining Time: 105min:44s
# Epoch: 84, Accuracy: 0.9869, Time: 15.18s, Avg. Time/Epoch: 15.21s, Remaining Time: 105min:28s
# Epoch: 85, Accuracy: 0.9886, Time: 15.19s, Avg. Time/Epoch: 15.21s, Remaining Time: 105min:13s
# Epoch: 86, Accuracy: 0.9872, Time: 15.18s, Avg. Time/Epoch: 15.21s, Remaining Time: 104min:58s
# Epoch: 87, Accuracy: 0.9873, Time: 15.18s, Avg. Time/Epoch: 15.21s, Remaining Time: 104min:42s
# Epoch: 88, Accuracy: 0.9857, Time: 15.18s, Avg. Time/Epoch: 15.21s, Remaining Time: 104min:27s
# Epoch: 89, Accuracy: 0.9869, Time: 15.19s, Avg. Time/Epoch: 15.21s, Remaining Time: 104min:12s
# Epoch: 90, Accuracy: 0.9854, Time: 15.18s, Avg. Time/Epoch: 15.21s, Remaining Time: 103min:56s
# Epoch: 91, Accuracy: 0.9865, Time: 15.17s, Avg. Time/Epoch: 15.21s, Remaining Time: 103min:41s
# Epoch: 92, Accuracy: 0.9889, Time: 15.18s, Avg. Time/Epoch: 15.21s, Remaining Time: 103min:26s
# Epoch: 93, Accuracy: 0.9888, Time: 15.18s, Avg. Time/Epoch: 15.21s, Remaining Time: 103min:10s
# Epoch: 94, Accuracy: 0.9843, Time: 15.18s, Avg. Time/Epoch: 15.21s, Remaining Time: 102min:55s
# Epoch: 95, Accuracy: 0.9876, Time: 15.17s, Avg. Time/Epoch: 15.21s, Remaining Time: 102min:40s
# Epoch: 96, Accuracy: 0.9895, Time: 15.17s, Avg. Time/Epoch: 15.21s, Remaining Time: 102min:24s
# Epoch: 97, Accuracy: 0.9876, Time: 15.17s, Avg. Time/Epoch: 15.21s, Remaining Time: 102min:9s
# Epoch: 98, Accuracy: 0.9880, Time: 15.19s, Avg. Time/Epoch: 15.21s, Remaining Time: 101min:54s
# Epoch: 99, Accuracy: 0.9866, Time: 15.18s, Avg. Time/Epoch: 15.21s, Remaining Time: 101min:38s
# Epoch: 100, Accuracy: 0.9880, Time: 15.18s, Avg. Time/Epoch: 15.21s, Remaining Time: 101min:23s
# Epoch: 101, Accuracy: 0.9897, Time: 15.18s, Avg. Time/Epoch: 15.21s, Remaining Time: 101min:8s
# Epoch: 102, Accuracy: 0.9877, Time: 15.19s, Avg. Time/Epoch: 15.21s, Remaining Time: 100min:52s
# Epoch: 103, Accuracy: 0.9825, Time: 15.17s, Avg. Time/Epoch: 15.21s, Remaining Time: 100min:37s
# Epoch: 104, Accuracy: 0.9877, Time: 15.17s, Avg. Time/Epoch: 15.21s, Remaining Time: 100min:22s
# Epoch: 105, Accuracy: 0.9896, Time: 15.17s, Avg. Time/Epoch: 15.21s, Remaining Time: 100min:6s
# Epoch: 106, Accuracy: 0.9893, Time: 15.18s, Avg. Time/Epoch: 15.21s, Remaining Time: 99min:51s
# Epoch: 107, Accuracy: 0.9898, Time: 15.18s, Avg. Time/Epoch: 15.21s, Remaining Time: 99min:36s
# Epoch: 108, Accuracy: 0.9884, Time: 15.19s, Avg. Time/Epoch: 15.21s, Remaining Time: 99min:20s
# Epoch: 109, Accuracy: 0.9900, Time: 15.19s, Avg. Time/Epoch: 15.20s, Remaining Time: 99min:5s
# Epoch: 110, Accuracy: 0.9885, Time: 15.19s, Avg. Time/Epoch: 15.20s, Remaining Time: 98min:50s
# Epoch: 111, Accuracy: 0.9873, Time: 15.17s, Avg. Time/Epoch: 15.20s, Remaining Time: 98min:35s
# Epoch: 112, Accuracy: 0.9900, Time: 15.19s, Avg. Time/Epoch: 15.20s, Remaining Time: 98min:19s
# Epoch: 113, Accuracy: 0.9859, Time: 15.17s, Avg. Time/Epoch: 15.20s, Remaining Time: 98min:4s
# Epoch: 114, Accuracy: 0.9778, Time: 15.18s, Avg. Time/Epoch: 15.20s, Remaining Time: 97min:49s
# Epoch: 115, Accuracy: 0.9789, Time: 15.16s, Avg. Time/Epoch: 15.20s, Remaining Time: 97min:33s
# Epoch: 116, Accuracy: 0.9817, Time: 15.16s, Avg. Time/Epoch: 15.20s, Remaining Time: 97min:18s
# Epoch: 117, Accuracy: 0.9857, Time: 15.16s, Avg. Time/Epoch: 15.20s, Remaining Time: 97min:3s
# Epoch: 118, Accuracy: 0.9856, Time: 15.16s, Avg. Time/Epoch: 15.20s, Remaining Time: 96min:47s
# Epoch: 119, Accuracy: 0.9853, Time: 15.16s, Avg. Time/Epoch: 15.20s, Remaining Time: 96min:32s
# Epoch: 120, Accuracy: 0.9848, Time: 15.16s, Avg. Time/Epoch: 15.20s, Remaining Time: 96min:17s
# Epoch: 121, Accuracy: 0.9848, Time: 15.16s, Avg. Time/Epoch: 15.20s, Remaining Time: 96min:1s
# Epoch: 122, Accuracy: 0.9870, Time: 15.17s, Avg. Time/Epoch: 15.20s, Remaining Time: 95min:46s
# Epoch: 123, Accuracy: 0.9848, Time: 15.17s, Avg. Time/Epoch: 15.20s, Remaining Time: 95min:31s
# Epoch: 124, Accuracy: 0.9884, Time: 15.19s, Avg. Time/Epoch: 15.20s, Remaining Time: 95min:15s
# Epoch: 125, Accuracy: 0.9843, Time: 15.19s, Avg. Time/Epoch: 15.20s, Remaining Time: 95min:0s
# Epoch: 126, Accuracy: 0.9861, Time: 15.20s, Avg. Time/Epoch: 15.20s, Remaining Time: 94min:45s
# Epoch: 127, Accuracy: 0.9889, Time: 15.15s, Avg. Time/Epoch: 15.20s, Remaining Time: 94min:30s
# Epoch: 128, Accuracy: 0.9892, Time: 15.16s, Avg. Time/Epoch: 15.20s, Remaining Time: 94min:14s
# Epoch: 129, Accuracy: 0.9895, Time: 15.17s, Avg. Time/Epoch: 15.20s, Remaining Time: 93min:59s
# Epoch: 130, Accuracy: 0.9888, Time: 15.18s, Avg. Time/Epoch: 15.20s, Remaining Time: 93min:44s
# Epoch: 131, Accuracy: 0.9893, Time: 15.17s, Avg. Time/Epoch: 15.20s, Remaining Time: 93min:29s
# Epoch: 132, Accuracy: 0.9879, Time: 15.18s, Avg. Time/Epoch: 15.20s, Remaining Time: 93min:13s
# Epoch: 133, Accuracy: 0.9895, Time: 15.18s, Avg. Time/Epoch: 15.20s, Remaining Time: 92min:58s
# Epoch: 134, Accuracy: 0.9906, Time: 15.19s, Avg. Time/Epoch: 15.20s, Remaining Time: 92min:43s
# Epoch: 135, Accuracy: 0.9889, Time: 15.17s, Avg. Time/Epoch: 15.20s, Remaining Time: 92min:28s
# Epoch: 136, Accuracy: 0.9882, Time: 15.17s, Avg. Time/Epoch: 15.20s, Remaining Time: 92min:12s
# Epoch: 137, Accuracy: 0.9897, Time: 15.16s, Avg. Time/Epoch: 15.20s, Remaining Time: 91min:57s
# Epoch: 138, Accuracy: 0.9903, Time: 15.18s, Avg. Time/Epoch: 15.20s, Remaining Time: 91min:42s
# Epoch: 139, Accuracy: 0.9893, Time: 15.17s, Avg. Time/Epoch: 15.20s, Remaining Time: 91min:26s
# Epoch: 140, Accuracy: 0.9872, Time: 15.16s, Avg. Time/Epoch: 15.20s, Remaining Time: 91min:11s
# Epoch: 141, Accuracy: 0.9882, Time: 15.16s, Avg. Time/Epoch: 15.20s, Remaining Time: 90min:56s
# Epoch: 142, Accuracy: 0.9896, Time: 15.19s, Avg. Time/Epoch: 15.20s, Remaining Time: 90min:41s
# Epoch: 143, Accuracy: 0.9898, Time: 15.17s, Avg. Time/Epoch: 15.20s, Remaining Time: 90min:25s
# Epoch: 144, Accuracy: 0.9897, Time: 15.18s, Avg. Time/Epoch: 15.20s, Remaining Time: 90min:10s
# Epoch: 145, Accuracy: 0.9906, Time: 15.17s, Avg. Time/Epoch: 15.20s, Remaining Time: 89min:55s
# Epoch: 146, Accuracy: 0.9904, Time: 15.16s, Avg. Time/Epoch: 15.20s, Remaining Time: 89min:40s
# Epoch: 147, Accuracy: 0.9860, Time: 15.16s, Avg. Time/Epoch: 15.20s, Remaining Time: 89min:24s
# Epoch: 148, Accuracy: 0.9896, Time: 15.17s, Avg. Time/Epoch: 15.20s, Remaining Time: 89min:9s
# Epoch: 149, Accuracy: 0.9891, Time: 15.16s, Avg. Time/Epoch: 15.20s, Remaining Time: 88min:54s
# Epoch: 150, Accuracy: 0.9872, Time: 15.17s, Avg. Time/Epoch: 15.20s, Remaining Time: 88min:38s
# Epoch: 151, Accuracy: 0.9886, Time: 15.16s, Avg. Time/Epoch: 15.20s, Remaining Time: 88min:23s
# Epoch: 152, Accuracy: 0.9863, Time: 15.16s, Avg. Time/Epoch: 15.20s, Remaining Time: 88min:8s
# Epoch: 153, Accuracy: 0.9905, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 87min:53s
# Epoch: 154, Accuracy: 0.9903, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 87min:37s
# Epoch: 155, Accuracy: 0.9890, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 87min:22s
# Epoch: 156, Accuracy: 0.9917, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 87min:7s
# Epoch: 157, Accuracy: 0.9902, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 86min:52s
# Epoch: 158, Accuracy: 0.9885, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 86min:36s
# Epoch: 159, Accuracy: 0.9885, Time: 15.15s, Avg. Time/Epoch: 15.19s, Remaining Time: 86min:21s
# Epoch: 160, Accuracy: 0.9905, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 86min:6s
# Epoch: 161, Accuracy: 0.9899, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 85min:51s
# Epoch: 162, Accuracy: 0.9887, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 85min:35s
# Epoch: 163, Accuracy: 0.9906, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 85min:20s
# Epoch: 164, Accuracy: 0.9857, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 85min:5s
# Epoch: 165, Accuracy: 0.9893, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 84min:50s
# Epoch: 166, Accuracy: 0.9891, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 84min:34s
# Epoch: 167, Accuracy: 0.9898, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 84min:19s
# Epoch: 168, Accuracy: 0.9891, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 84min:4s
# Epoch: 169, Accuracy: 0.9795, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 83min:49s
# Epoch: 170, Accuracy: 0.9877, Time: 15.21s, Avg. Time/Epoch: 15.19s, Remaining Time: 83min:33s
# Epoch: 171, Accuracy: 0.9906, Time: 15.21s, Avg. Time/Epoch: 15.19s, Remaining Time: 83min:18s
# Epoch: 172, Accuracy: 0.9906, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 83min:3s
# Epoch: 173, Accuracy: 0.9904, Time: 15.19s, Avg. Time/Epoch: 15.19s, Remaining Time: 82min:48s
# Epoch: 174, Accuracy: 0.9891, Time: 15.20s, Avg. Time/Epoch: 15.19s, Remaining Time: 82min:33s
# Epoch: 175, Accuracy: 0.9847, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 82min:18s
# Epoch: 176, Accuracy: 0.9889, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 82min:2s
# Epoch: 177, Accuracy: 0.9893, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 81min:47s
# Epoch: 178, Accuracy: 0.9909, Time: 15.19s, Avg. Time/Epoch: 15.19s, Remaining Time: 81min:32s
# Epoch: 179, Accuracy: 0.9879, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 81min:17s
# Epoch: 180, Accuracy: 0.9883, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 81min:1s
# Epoch: 181, Accuracy: 0.9852, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 80min:46s
# Epoch: 182, Accuracy: 0.9878, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 80min:31s
# Epoch: 183, Accuracy: 0.9876, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 80min:16s
# Epoch: 184, Accuracy: 0.9884, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 80min:0s
# Epoch: 185, Accuracy: 0.9873, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 79min:45s
# Epoch: 186, Accuracy: 0.9867, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 79min:30s
# Epoch: 187, Accuracy: 0.9902, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 79min:15s
# Epoch: 188, Accuracy: 0.9870, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 78min:60s
# Epoch: 189, Accuracy: 0.9872, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 78min:44s
# Epoch: 190, Accuracy: 0.9874, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 78min:29s
# Epoch: 191, Accuracy: 0.9883, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 78min:14s
# Epoch: 192, Accuracy: 0.9888, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 77min:59s
# Epoch: 193, Accuracy: 0.9898, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 77min:43s
# Epoch: 194, Accuracy: 0.9885, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 77min:28s
# Epoch: 195, Accuracy: 0.9911, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 77min:13s
# Epoch: 196, Accuracy: 0.9889, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 76min:58s
# Epoch: 197, Accuracy: 0.9900, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 76min:43s
# Epoch: 198, Accuracy: 0.9908, Time: 15.19s, Avg. Time/Epoch: 15.19s, Remaining Time: 76min:27s
# Epoch: 199, Accuracy: 0.9896, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 76min:12s
# Epoch: 200, Accuracy: 0.9902, Time: 15.20s, Avg. Time/Epoch: 15.19s, Remaining Time: 75min:57s
# Epoch: 201, Accuracy: 0.9919, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 75min:42s
# Epoch: 202, Accuracy: 0.9902, Time: 15.19s, Avg. Time/Epoch: 15.19s, Remaining Time: 75min:27s
# Epoch: 203, Accuracy: 0.9909, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 75min:11s
# Epoch: 204, Accuracy: 0.9903, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 74min:56s
# Epoch: 205, Accuracy: 0.9900, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 74min:41s
# Epoch: 206, Accuracy: 0.9894, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 74min:26s
# Epoch: 207, Accuracy: 0.9889, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 74min:10s
# Epoch: 208, Accuracy: 0.9911, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 73min:55s
# Epoch: 209, Accuracy: 0.9913, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 73min:40s
# Epoch: 210, Accuracy: 0.9886, Time: 15.21s, Avg. Time/Epoch: 15.19s, Remaining Time: 73min:25s
# Epoch: 211, Accuracy: 0.9914, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 73min:10s
# Epoch: 212, Accuracy: 0.9891, Time: 15.19s, Avg. Time/Epoch: 15.19s, Remaining Time: 72min:55s
# Epoch: 213, Accuracy: 0.9888, Time: 15.19s, Avg. Time/Epoch: 15.19s, Remaining Time: 72min:39s
# Epoch: 214, Accuracy: 0.9895, Time: 15.19s, Avg. Time/Epoch: 15.19s, Remaining Time: 72min:24s
# Epoch: 215, Accuracy: 0.9918, Time: 15.19s, Avg. Time/Epoch: 15.19s, Remaining Time: 72min:9s
# Epoch: 216, Accuracy: 0.9895, Time: 15.19s, Avg. Time/Epoch: 15.19s, Remaining Time: 71min:54s
# Epoch: 217, Accuracy: 0.9915, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 71min:39s
# Epoch: 218, Accuracy: 0.9914, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 71min:23s
# Epoch: 219, Accuracy: 0.9901, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 71min:8s
# Epoch: 220, Accuracy: 0.9906, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 70min:53s
# Epoch: 221, Accuracy: 0.9866, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 70min:38s
# Epoch: 222, Accuracy: 0.9905, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 70min:22s
# Epoch: 223, Accuracy: 0.9892, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 70min:7s
# Epoch: 224, Accuracy: 0.9895, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 69min:52s
# Epoch: 225, Accuracy: 0.9909, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 69min:37s
# Epoch: 226, Accuracy: 0.9883, Time: 15.19s, Avg. Time/Epoch: 15.19s, Remaining Time: 69min:22s
# Epoch: 227, Accuracy: 0.9900, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 69min:6s
# Epoch: 228, Accuracy: 0.9914, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 68min:51s
# Epoch: 229, Accuracy: 0.9903, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 68min:36s
# Epoch: 230, Accuracy: 0.9878, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 68min:21s
# Epoch: 231, Accuracy: 0.9911, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 68min:6s
# Epoch: 232, Accuracy: 0.9895, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 67min:50s
# Epoch: 233, Accuracy: 0.9894, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 67min:35s
# Epoch: 234, Accuracy: 0.9911, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 67min:20s
# Epoch: 235, Accuracy: 0.9906, Time: 15.16s, Avg. Time/Epoch: 15.19s, Remaining Time: 67min:5s
# Epoch: 236, Accuracy: 0.9909, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 66min:50s
# Epoch: 237, Accuracy: 0.9897, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 66min:34s
# Epoch: 238, Accuracy: 0.9889, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 66min:19s
# Epoch: 239, Accuracy: 0.9915, Time: 15.17s, Avg. Time/Epoch: 15.19s, Remaining Time: 66min:4s
# Epoch: 240, Accuracy: 0.9905, Time: 15.18s, Avg. Time/Epoch: 15.19s, Remaining Time: 65min:49s
# Epoch: 241, Accuracy: 0.9913, Time: 30.07s, Avg. Time/Epoch: 15.25s, Remaining Time: 65min:50s
# Epoch: 242, Accuracy: 0.9908, Time: 43.01s, Avg. Time/Epoch: 15.36s, Remaining Time: 66min:4s
# Epoch: 243, Accuracy: 0.9904, Time: 43.02s, Avg. Time/Epoch: 15.48s, Remaining Time: 66min:18s
# Epoch: 244, Accuracy: 0.9908, Time: 40.71s, Avg. Time/Epoch: 15.58s, Remaining Time: 66min:29s
# Epoch: 245, Accuracy: 0.9918, Time: 43.05s, Avg. Time/Epoch: 15.69s, Remaining Time: 66min:42s
# Epoch: 246, Accuracy: 0.9923, Time: 43.13s, Avg. Time/Epoch: 15.80s, Remaining Time: 66min:54s
# Epoch: 247, Accuracy: 0.9903, Time: 43.09s, Avg. Time/Epoch: 15.92s, Remaining Time: 67min:7s
# Epoch: 248, Accuracy: 0.9912, Time: 31.63s, Avg. Time/Epoch: 15.98s, Remaining Time: 67min:7s
# Epoch: 249, Accuracy: 0.9889, Time: 15.17s, Avg. Time/Epoch: 15.98s, Remaining Time: 66min:50s
# Epoch: 250, Accuracy: 0.9924, Time: 15.19s, Avg. Time/Epoch: 15.97s, Remaining Time: 66min:33s
# Epoch: 251, Accuracy: 0.9872, Time: 15.18s, Avg. Time/Epoch: 15.97s, Remaining Time: 66min:16s
# Epoch: 252, Accuracy: 0.9887, Time: 15.18s, Avg. Time/Epoch: 15.97s, Remaining Time: 65min:60s
# Epoch: 253, Accuracy: 0.9909, Time: 15.19s, Avg. Time/Epoch: 15.96s, Remaining Time: 65min:43s
# Epoch: 254, Accuracy: 0.9910, Time: 15.20s, Avg. Time/Epoch: 15.96s, Remaining Time: 65min:26s
# Epoch: 255, Accuracy: 0.9920, Time: 15.18s, Avg. Time/Epoch: 15.96s, Remaining Time: 65min:9s
# Epoch: 256, Accuracy: 0.9905, Time: 15.20s, Avg. Time/Epoch: 15.95s, Remaining Time: 64min:53s
# Epoch: 257, Accuracy: 0.9897, Time: 15.19s, Avg. Time/Epoch: 15.95s, Remaining Time: 64min:36s
# Epoch: 258, Accuracy: 0.9906, Time: 15.21s, Avg. Time/Epoch: 15.95s, Remaining Time: 64min:19s
# Epoch: 259, Accuracy: 0.9901, Time: 15.17s, Avg. Time/Epoch: 15.95s, Remaining Time: 64min:3s
# Epoch: 260, Accuracy: 0.9915, Time: 15.20s, Avg. Time/Epoch: 15.94s, Remaining Time: 63min:46s
# Epoch: 261, Accuracy: 0.9917, Time: 15.19s, Avg. Time/Epoch: 15.94s, Remaining Time: 63min:30s
# Epoch: 262, Accuracy: 0.9916, Time: 15.20s, Avg. Time/Epoch: 15.94s, Remaining Time: 63min:13s
# Epoch: 263, Accuracy: 0.9892, Time: 15.18s, Avg. Time/Epoch: 15.93s, Remaining Time: 62min:56s
# Epoch: 264, Accuracy: 0.9903, Time: 15.17s, Avg. Time/Epoch: 15.93s, Remaining Time: 62min:40s
# Epoch: 265, Accuracy: 0.9906, Time: 15.17s, Avg. Time/Epoch: 15.93s, Remaining Time: 62min:23s
# Epoch: 266, Accuracy: 0.9855, Time: 15.20s, Avg. Time/Epoch: 15.93s, Remaining Time: 62min:6s
# Epoch: 267, Accuracy: 0.9920, Time: 15.18s, Avg. Time/Epoch: 15.92s, Remaining Time: 61min:50s
# Epoch: 268, Accuracy: 0.9911, Time: 15.18s, Avg. Time/Epoch: 15.92s, Remaining Time: 61min:33s
# Epoch: 269, Accuracy: 0.9908, Time: 15.18s, Avg. Time/Epoch: 15.92s, Remaining Time: 61min:17s
# Epoch: 270, Accuracy: 0.9901, Time: 15.17s, Avg. Time/Epoch: 15.91s, Remaining Time: 61min:0s
# Epoch: 271, Accuracy: 0.9909, Time: 15.16s, Avg. Time/Epoch: 15.91s, Remaining Time: 60min:44s
# Epoch: 272, Accuracy: 0.9918, Time: 15.18s, Avg. Time/Epoch: 15.91s, Remaining Time: 60min:27s
# Epoch: 273, Accuracy: 0.9923, Time: 15.17s, Avg. Time/Epoch: 15.91s, Remaining Time: 60min:11s
# Epoch: 274, Accuracy: 0.9874, Time: 15.17s, Avg. Time/Epoch: 15.90s, Remaining Time: 59min:54s
# Epoch: 275, Accuracy: 0.9908, Time: 15.16s, Avg. Time/Epoch: 15.90s, Remaining Time: 59min:38s
# Epoch: 276, Accuracy: 0.9903, Time: 15.17s, Avg. Time/Epoch: 15.90s, Remaining Time: 59min:21s
# Epoch: 277, Accuracy: 0.9858, Time: 15.18s, Avg. Time/Epoch: 15.90s, Remaining Time: 59min:5s
# Epoch: 278, Accuracy: 0.9909, Time: 15.17s, Avg. Time/Epoch: 15.89s, Remaining Time: 58min:48s
# Epoch: 279, Accuracy: 0.9910, Time: 15.16s, Avg. Time/Epoch: 15.89s, Remaining Time: 58min:32s
# Epoch: 280, Accuracy: 0.9909, Time: 15.17s, Avg. Time/Epoch: 15.89s, Remaining Time: 58min:15s
# Epoch: 281, Accuracy: 0.9910, Time: 15.19s, Avg. Time/Epoch: 15.89s, Remaining Time: 57min:59s
# Epoch: 282, Accuracy: 0.9907, Time: 15.19s, Avg. Time/Epoch: 15.88s, Remaining Time: 57min:42s
# Epoch: 283, Accuracy: 0.9909, Time: 15.17s, Avg. Time/Epoch: 15.88s, Remaining Time: 57min:26s
# Epoch: 284, Accuracy: 0.9922, Time: 15.17s, Avg. Time/Epoch: 15.88s, Remaining Time: 57min:10s
# Epoch: 285, Accuracy: 0.9910, Time: 15.16s, Avg. Time/Epoch: 15.88s, Remaining Time: 56min:53s
# Epoch: 286, Accuracy: 0.9908, Time: 15.19s, Avg. Time/Epoch: 15.87s, Remaining Time: 56min:37s
# Epoch: 287, Accuracy: 0.9925, Time: 15.17s, Avg. Time/Epoch: 15.87s, Remaining Time: 56min:20s
# Epoch: 288, Accuracy: 0.9921, Time: 15.17s, Avg. Time/Epoch: 15.87s, Remaining Time: 56min:4s
# Epoch: 289, Accuracy: 0.9909, Time: 15.19s, Avg. Time/Epoch: 15.87s, Remaining Time: 55min:48s
# Epoch: 290, Accuracy: 0.9903, Time: 15.19s, Avg. Time/Epoch: 15.86s, Remaining Time: 55min:31s
# Epoch: 291, Accuracy: 0.9903, Time: 15.16s, Avg. Time/Epoch: 15.86s, Remaining Time: 55min:15s
# Epoch: 292, Accuracy: 0.9910, Time: 15.16s, Avg. Time/Epoch: 15.86s, Remaining Time: 54min:59s
# Epoch: 293, Accuracy: 0.9915, Time: 15.18s, Avg. Time/Epoch: 15.86s, Remaining Time: 54min:42s
# Epoch: 294, Accuracy: 0.9895, Time: 15.19s, Avg. Time/Epoch: 15.85s, Remaining Time: 54min:26s
# Epoch: 295, Accuracy: 0.9905, Time: 15.16s, Avg. Time/Epoch: 15.85s, Remaining Time: 54min:10s
# Epoch: 296, Accuracy: 0.9907, Time: 15.16s, Avg. Time/Epoch: 15.85s, Remaining Time: 53min:53s
# Epoch: 297, Accuracy: 0.9905, Time: 15.16s, Avg. Time/Epoch: 15.85s, Remaining Time: 53min:37s
# Epoch: 298, Accuracy: 0.9899, Time: 15.17s, Avg. Time/Epoch: 15.84s, Remaining Time: 53min:21s
# Epoch: 299, Accuracy: 0.9896, Time: 15.18s, Avg. Time/Epoch: 15.84s, Remaining Time: 53min:4s
# Epoch: 300, Accuracy: 0.9909, Time: 15.18s, Avg. Time/Epoch: 15.84s, Remaining Time: 52min:48s
# Epoch: 301, Accuracy: 0.9920, Time: 15.18s, Avg. Time/Epoch: 15.84s, Remaining Time: 52min:32s
# Epoch: 302, Accuracy: 0.9918, Time: 15.18s, Avg. Time/Epoch: 15.84s, Remaining Time: 52min:15s
# Epoch: 303, Accuracy: 0.9892, Time: 15.17s, Avg. Time/Epoch: 15.83s, Remaining Time: 51min:59s
# Epoch: 304, Accuracy: 0.9893, Time: 15.18s, Avg. Time/Epoch: 15.83s, Remaining Time: 51min:43s
# Epoch: 305, Accuracy: 0.9913, Time: 15.17s, Avg. Time/Epoch: 15.83s, Remaining Time: 51min:27s
# Epoch: 306, Accuracy: 0.9887, Time: 15.17s, Avg. Time/Epoch: 15.83s, Remaining Time: 51min:10s
# Epoch: 307, Accuracy: 0.9911, Time: 15.16s, Avg. Time/Epoch: 15.82s, Remaining Time: 50min:54s
# Epoch: 308, Accuracy: 0.9909, Time: 15.16s, Avg. Time/Epoch: 15.82s, Remaining Time: 50min:38s
# Epoch: 309, Accuracy: 0.9899, Time: 15.17s, Avg. Time/Epoch: 15.82s, Remaining Time: 50min:22s
# Epoch: 310, Accuracy: 0.9922, Time: 15.18s, Avg. Time/Epoch: 15.82s, Remaining Time: 50min:6s
# Epoch: 311, Accuracy: 0.9889, Time: 15.16s, Avg. Time/Epoch: 15.82s, Remaining Time: 49min:49s
# Epoch: 312, Accuracy: 0.9879, Time: 15.17s, Avg. Time/Epoch: 15.81s, Remaining Time: 49min:33s
# Epoch: 313, Accuracy: 0.9910, Time: 15.16s, Avg. Time/Epoch: 15.81s, Remaining Time: 49min:17s
# Epoch: 314, Accuracy: 0.9900, Time: 15.16s, Avg. Time/Epoch: 15.81s, Remaining Time: 49min:1s
# Epoch: 315, Accuracy: 0.9916, Time: 15.17s, Avg. Time/Epoch: 15.81s, Remaining Time: 48min:44s
# Epoch: 316, Accuracy: 0.9904, Time: 15.18s, Avg. Time/Epoch: 15.81s, Remaining Time: 48min:28s
# Epoch: 317, Accuracy: 0.9898, Time: 15.17s, Avg. Time/Epoch: 15.80s, Remaining Time: 48min:12s
# Epoch: 318, Accuracy: 0.9915, Time: 15.20s, Avg. Time/Epoch: 15.80s, Remaining Time: 47min:56s
# Epoch: 319, Accuracy: 0.9911, Time: 15.17s, Avg. Time/Epoch: 15.80s, Remaining Time: 47min:40s
# Epoch: 320, Accuracy: 0.9918, Time: 15.17s, Avg. Time/Epoch: 15.80s, Remaining Time: 47min:24s
# Epoch: 321, Accuracy: 0.9909, Time: 15.16s, Avg. Time/Epoch: 15.80s, Remaining Time: 47min:8s
# Epoch: 322, Accuracy: 0.9911, Time: 15.18s, Avg. Time/Epoch: 15.79s, Remaining Time: 46min:51s
# Epoch: 323, Accuracy: 0.9905, Time: 15.17s, Avg. Time/Epoch: 15.79s, Remaining Time: 46min:35s
# Epoch: 324, Accuracy: 0.9862, Time: 15.16s, Avg. Time/Epoch: 15.79s, Remaining Time: 46min:19s
# Epoch: 325, Accuracy: 0.9914, Time: 15.16s, Avg. Time/Epoch: 15.79s, Remaining Time: 46min:3s
# Epoch: 326, Accuracy: 0.9912, Time: 15.18s, Avg. Time/Epoch: 15.79s, Remaining Time: 45min:47s
# Epoch: 327, Accuracy: 0.9905, Time: 15.16s, Avg. Time/Epoch: 15.78s, Remaining Time: 45min:31s
# Epoch: 328, Accuracy: 0.9883, Time: 15.17s, Avg. Time/Epoch: 15.78s, Remaining Time: 45min:15s
# Epoch: 329, Accuracy: 0.9910, Time: 15.17s, Avg. Time/Epoch: 15.78s, Remaining Time: 44min:59s
# Epoch: 330, Accuracy: 0.9907, Time: 15.17s, Avg. Time/Epoch: 15.78s, Remaining Time: 44min:42s
# Epoch: 331, Accuracy: 0.9917, Time: 15.16s, Avg. Time/Epoch: 15.78s, Remaining Time: 44min:26s
# Epoch: 332, Accuracy: 0.9912, Time: 15.17s, Avg. Time/Epoch: 15.78s, Remaining Time: 44min:10s
# Epoch: 333, Accuracy: 0.9907, Time: 15.17s, Avg. Time/Epoch: 15.77s, Remaining Time: 43min:54s
# Epoch: 334, Accuracy: 0.9910, Time: 15.17s, Avg. Time/Epoch: 15.77s, Remaining Time: 43min:38s
# Epoch: 335, Accuracy: 0.9919, Time: 15.16s, Avg. Time/Epoch: 15.77s, Remaining Time: 43min:22s
# Epoch: 336, Accuracy: 0.9907, Time: 15.17s, Avg. Time/Epoch: 15.77s, Remaining Time: 43min:6s
# Epoch: 337, Accuracy: 0.9887, Time: 15.17s, Avg. Time/Epoch: 15.77s, Remaining Time: 42min:50s
# Epoch: 338, Accuracy: 0.9913, Time: 15.18s, Avg. Time/Epoch: 15.76s, Remaining Time: 42min:34s
# Epoch: 339, Accuracy: 0.9922, Time: 15.17s, Avg. Time/Epoch: 15.76s, Remaining Time: 42min:18s
# Epoch: 340, Accuracy: 0.9892, Time: 15.16s, Avg. Time/Epoch: 15.76s, Remaining Time: 42min:2s
# Epoch: 341, Accuracy: 0.9912, Time: 15.16s, Avg. Time/Epoch: 15.76s, Remaining Time: 41min:46s
# Epoch: 342, Accuracy: 0.9907, Time: 15.17s, Avg. Time/Epoch: 15.76s, Remaining Time: 41min:30s
# Epoch: 343, Accuracy: 0.9912, Time: 15.17s, Avg. Time/Epoch: 15.76s, Remaining Time: 41min:14s
# Epoch: 344, Accuracy: 0.9886, Time: 15.17s, Avg. Time/Epoch: 15.75s, Remaining Time: 40min:58s
# Epoch: 345, Accuracy: 0.9907, Time: 15.17s, Avg. Time/Epoch: 15.75s, Remaining Time: 40min:42s
# Epoch: 346, Accuracy: 0.9917, Time: 15.20s, Avg. Time/Epoch: 15.75s, Remaining Time: 40min:26s
# Epoch: 347, Accuracy: 0.9919, Time: 15.18s, Avg. Time/Epoch: 15.75s, Remaining Time: 40min:10s
# Epoch: 348, Accuracy: 0.9895, Time: 15.18s, Avg. Time/Epoch: 15.75s, Remaining Time: 39min:54s
# Epoch: 349, Accuracy: 0.9855, Time: 15.18s, Avg. Time/Epoch: 15.75s, Remaining Time: 39min:38s
# Epoch: 350, Accuracy: 0.9912, Time: 15.19s, Avg. Time/Epoch: 15.74s, Remaining Time: 39min:22s
# Epoch: 351, Accuracy: 0.9906, Time: 15.17s, Avg. Time/Epoch: 15.74s, Remaining Time: 39min:6s
# Epoch: 352, Accuracy: 0.9867, Time: 15.17s, Avg. Time/Epoch: 15.74s, Remaining Time: 38min:50s
# Epoch: 353, Accuracy: 0.9913, Time: 15.17s, Avg. Time/Epoch: 15.74s, Remaining Time: 38min:34s
# Epoch: 354, Accuracy: 0.9913, Time: 15.16s, Avg. Time/Epoch: 15.74s, Remaining Time: 38min:18s
# Epoch: 355, Accuracy: 0.9886, Time: 15.15s, Avg. Time/Epoch: 15.74s, Remaining Time: 38min:2s
# Epoch: 356, Accuracy: 0.9922, Time: 15.17s, Avg. Time/Epoch: 15.73s, Remaining Time: 37min:46s
# Epoch: 357, Accuracy: 0.9887, Time: 15.17s, Avg. Time/Epoch: 15.73s, Remaining Time: 37min:30s
# Epoch: 358, Accuracy: 0.9908, Time: 15.17s, Avg. Time/Epoch: 15.73s, Remaining Time: 37min:14s
# Epoch: 359, Accuracy: 0.9918, Time: 15.16s, Avg. Time/Epoch: 15.73s, Remaining Time: 36min:58s
# Epoch: 360, Accuracy: 0.9926, Time: 15.16s, Avg. Time/Epoch: 15.73s, Remaining Time: 36min:42s
# Epoch: 361, Accuracy: 0.9922, Time: 15.16s, Avg. Time/Epoch: 15.73s, Remaining Time: 36min:26s
# Epoch: 362, Accuracy: 0.9912, Time: 15.17s, Avg. Time/Epoch: 15.73s, Remaining Time: 36min:10s
# Epoch: 363, Accuracy: 0.9915, Time: 15.16s, Avg. Time/Epoch: 15.72s, Remaining Time: 35min:54s
# Epoch: 364, Accuracy: 0.9891, Time: 15.17s, Avg. Time/Epoch: 15.72s, Remaining Time: 35min:38s
# Epoch: 365, Accuracy: 0.9888, Time: 15.16s, Avg. Time/Epoch: 15.72s, Remaining Time: 35min:22s
# Epoch: 366, Accuracy: 0.9885, Time: 15.16s, Avg. Time/Epoch: 15.72s, Remaining Time: 35min:6s
# Epoch: 367, Accuracy: 0.9910, Time: 15.16s, Avg. Time/Epoch: 15.72s, Remaining Time: 34min:50s
# Epoch: 368, Accuracy: 0.9911, Time: 15.16s, Avg. Time/Epoch: 15.72s, Remaining Time: 34min:35s
# Epoch: 369, Accuracy: 0.9913, Time: 15.16s, Avg. Time/Epoch: 15.71s, Remaining Time: 34min:19s
# Epoch: 370, Accuracy: 0.9921, Time: 15.17s, Avg. Time/Epoch: 15.71s, Remaining Time: 34min:3s
# Epoch: 371, Accuracy: 0.9926, Time: 15.16s, Avg. Time/Epoch: 15.71s, Remaining Time: 33min:47s
# Epoch: 372, Accuracy: 0.9887, Time: 15.17s, Avg. Time/Epoch: 15.71s, Remaining Time: 33min:31s
# Epoch: 373, Accuracy: 0.9885, Time: 15.17s, Avg. Time/Epoch: 15.71s, Remaining Time: 33min:15s
# Epoch: 374, Accuracy: 0.9914, Time: 15.18s, Avg. Time/Epoch: 15.71s, Remaining Time: 32min:59s
# Epoch: 375, Accuracy: 0.9921, Time: 15.17s, Avg. Time/Epoch: 15.71s, Remaining Time: 32min:43s
# Epoch: 376, Accuracy: 0.9922, Time: 15.18s, Avg. Time/Epoch: 15.70s, Remaining Time: 32min:27s
# Epoch: 377, Accuracy: 0.9882, Time: 15.16s, Avg. Time/Epoch: 15.70s, Remaining Time: 32min:11s
# Epoch: 378, Accuracy: 0.9838, Time: 15.17s, Avg. Time/Epoch: 15.70s, Remaining Time: 31min:56s
# Epoch: 379, Accuracy: 0.9913, Time: 15.16s, Avg. Time/Epoch: 15.70s, Remaining Time: 31min:40s
# Epoch: 380, Accuracy: 0.9909, Time: 15.16s, Avg. Time/Epoch: 15.70s, Remaining Time: 31min:24s
# Epoch: 381, Accuracy: 0.9910, Time: 15.16s, Avg. Time/Epoch: 15.70s, Remaining Time: 31min:8s
# Epoch: 382, Accuracy: 0.9921, Time: 15.17s, Avg. Time/Epoch: 15.70s, Remaining Time: 30min:52s
# Epoch: 383, Accuracy: 0.9911, Time: 15.16s, Avg. Time/Epoch: 15.69s, Remaining Time: 30min:36s
# Epoch: 384, Accuracy: 0.9906, Time: 15.16s, Avg. Time/Epoch: 15.69s, Remaining Time: 30min:20s
# Epoch: 385, Accuracy: 0.9901, Time: 15.17s, Avg. Time/Epoch: 15.69s, Remaining Time: 30min:5s
# Epoch: 386, Accuracy: 0.9915, Time: 15.19s, Avg. Time/Epoch: 15.69s, Remaining Time: 29min:49s
# Epoch: 387, Accuracy: 0.9925, Time: 15.17s, Avg. Time/Epoch: 15.69s, Remaining Time: 29min:33s
# Epoch: 388, Accuracy: 0.9896, Time: 15.19s, Avg. Time/Epoch: 15.69s, Remaining Time: 29min:17s
# Epoch: 389, Accuracy: 0.9925, Time: 15.18s, Avg. Time/Epoch: 15.69s, Remaining Time: 29min:1s
# Epoch: 390, Accuracy: 0.9900, Time: 15.19s, Avg. Time/Epoch: 15.69s, Remaining Time: 28min:45s
# Epoch: 391, Accuracy: 0.9914, Time: 15.17s, Avg. Time/Epoch: 15.68s, Remaining Time: 28min:30s
# Epoch: 392, Accuracy: 0.9879, Time: 15.18s, Avg. Time/Epoch: 15.68s, Remaining Time: 28min:14s
# Epoch: 393, Accuracy: 0.9922, Time: 15.18s, Avg. Time/Epoch: 15.68s, Remaining Time: 27min:58s
# Epoch: 394, Accuracy: 0.9915, Time: 15.17s, Avg. Time/Epoch: 15.68s, Remaining Time: 27min:42s
# Epoch: 395, Accuracy: 0.9912, Time: 15.15s, Avg. Time/Epoch: 15.68s, Remaining Time: 27min:26s
# Epoch: 396, Accuracy: 0.9906, Time: 15.16s, Avg. Time/Epoch: 15.68s, Remaining Time: 27min:10s
# Epoch: 397, Accuracy: 0.9922, Time: 15.16s, Avg. Time/Epoch: 15.68s, Remaining Time: 26min:55s
# Epoch: 398, Accuracy: 0.9922, Time: 15.17s, Avg. Time/Epoch: 15.67s, Remaining Time: 26min:39s
# Epoch: 399, Accuracy: 0.9914, Time: 15.14s, Avg. Time/Epoch: 15.67s, Remaining Time: 26min:23s
# Epoch: 400, Accuracy: 0.9921, Time: 15.15s, Avg. Time/Epoch: 15.67s, Remaining Time: 26min:7s
# Epoch: 401, Accuracy: 0.9901, Time: 15.14s, Avg. Time/Epoch: 15.67s, Remaining Time: 25min:51s
# Epoch: 402, Accuracy: 0.9899, Time: 15.17s, Avg. Time/Epoch: 15.67s, Remaining Time: 25min:36s
# Epoch: 403, Accuracy: 0.9903, Time: 15.16s, Avg. Time/Epoch: 15.67s, Remaining Time: 25min:20s
# Epoch: 404, Accuracy: 0.9917, Time: 15.17s, Avg. Time/Epoch: 15.67s, Remaining Time: 25min:4s
# Epoch: 405, Accuracy: 0.9902, Time: 15.17s, Avg. Time/Epoch: 15.67s, Remaining Time: 24min:48s
# Epoch: 406, Accuracy: 0.9896, Time: 15.17s, Avg. Time/Epoch: 15.66s, Remaining Time: 24min:32s
# Epoch: 407, Accuracy: 0.9920, Time: 15.16s, Avg. Time/Epoch: 15.66s, Remaining Time: 24min:17s
# Epoch: 408, Accuracy: 0.9919, Time: 15.17s, Avg. Time/Epoch: 15.66s, Remaining Time: 24min:1s
# Epoch: 409, Accuracy: 0.9926, Time: 15.15s, Avg. Time/Epoch: 15.66s, Remaining Time: 23min:45s
# Epoch: 410, Accuracy: 0.9920, Time: 15.16s, Avg. Time/Epoch: 15.66s, Remaining Time: 23min:29s
# Epoch: 411, Accuracy: 0.9924, Time: 15.14s, Avg. Time/Epoch: 15.66s, Remaining Time: 23min:14s
# Epoch: 412, Accuracy: 0.9907, Time: 15.14s, Avg. Time/Epoch: 15.66s, Remaining Time: 22min:58s
# Epoch: 413, Accuracy: 0.9919, Time: 15.15s, Avg. Time/Epoch: 15.66s, Remaining Time: 22min:42s
# Epoch: 414, Accuracy: 0.9898, Time: 15.16s, Avg. Time/Epoch: 15.65s, Remaining Time: 22min:26s
# Epoch: 415, Accuracy: 0.9911, Time: 15.15s, Avg. Time/Epoch: 15.65s, Remaining Time: 22min:11s
# Epoch: 416, Accuracy: 0.9916, Time: 15.16s, Avg. Time/Epoch: 15.65s, Remaining Time: 21min:55s
# Epoch: 417, Accuracy: 0.9924, Time: 15.15s, Avg. Time/Epoch: 15.65s, Remaining Time: 21min:39s
# Epoch: 418, Accuracy: 0.9902, Time: 15.16s, Avg. Time/Epoch: 15.65s, Remaining Time: 21min:23s
# Epoch: 419, Accuracy: 0.9930, Time: 15.15s, Avg. Time/Epoch: 15.65s, Remaining Time: 21min:8s
# Epoch: 420, Accuracy: 0.9909, Time: 15.16s, Avg. Time/Epoch: 15.65s, Remaining Time: 20min:52s
# Epoch: 421, Accuracy: 0.9912, Time: 15.16s, Avg. Time/Epoch: 15.65s, Remaining Time: 20min:36s
# Epoch: 422, Accuracy: 0.9919, Time: 15.17s, Avg. Time/Epoch: 15.65s, Remaining Time: 20min:20s
# Epoch: 423, Accuracy: 0.9916, Time: 15.15s, Avg. Time/Epoch: 15.64s, Remaining Time: 20min:5s
# Epoch: 424, Accuracy: 0.9904, Time: 15.15s, Avg. Time/Epoch: 15.64s, Remaining Time: 19min:49s
# Epoch: 425, Accuracy: 0.9910, Time: 15.16s, Avg. Time/Epoch: 15.64s, Remaining Time: 19min:33s
# Epoch: 426, Accuracy: 0.9923, Time: 15.16s, Avg. Time/Epoch: 15.64s, Remaining Time: 19min:17s
# Epoch: 427, Accuracy: 0.9924, Time: 15.15s, Avg. Time/Epoch: 15.64s, Remaining Time: 19min:2s
# Epoch: 428, Accuracy: 0.9912, Time: 15.16s, Avg. Time/Epoch: 15.64s, Remaining Time: 18min:46s
# Epoch: 429, Accuracy: 0.9887, Time: 15.16s, Avg. Time/Epoch: 15.64s, Remaining Time: 18min:30s
# Epoch: 430, Accuracy: 0.9910, Time: 15.16s, Avg. Time/Epoch: 15.64s, Remaining Time: 18min:15s
# Epoch: 431, Accuracy: 0.9917, Time: 15.14s, Avg. Time/Epoch: 15.64s, Remaining Time: 17min:59s
# Epoch: 432, Accuracy: 0.9909, Time: 15.16s, Avg. Time/Epoch: 15.63s, Remaining Time: 17min:43s
# Epoch: 433, Accuracy: 0.9895, Time: 15.17s, Avg. Time/Epoch: 15.63s, Remaining Time: 17min:27s
# Epoch: 434, Accuracy: 0.9911, Time: 15.18s, Avg. Time/Epoch: 15.63s, Remaining Time: 17min:12s
# Epoch: 435, Accuracy: 0.9923, Time: 15.16s, Avg. Time/Epoch: 15.63s, Remaining Time: 16min:56s
# Epoch: 436, Accuracy: 0.9920, Time: 15.16s, Avg. Time/Epoch: 15.63s, Remaining Time: 16min:40s
# Epoch: 437, Accuracy: 0.9903, Time: 15.16s, Avg. Time/Epoch: 15.63s, Remaining Time: 16min:25s
# Epoch: 438, Accuracy: 0.9918, Time: 15.17s, Avg. Time/Epoch: 15.63s, Remaining Time: 16min:9s
# Epoch: 439, Accuracy: 0.9917, Time: 15.15s, Avg. Time/Epoch: 15.63s, Remaining Time: 15min:53s
# Epoch: 440, Accuracy: 0.9904, Time: 15.16s, Avg. Time/Epoch: 15.63s, Remaining Time: 15min:38s
# Epoch: 441, Accuracy: 0.9923, Time: 15.16s, Avg. Time/Epoch: 15.62s, Remaining Time: 15min:22s
# Epoch: 442, Accuracy: 0.9922, Time: 15.17s, Avg. Time/Epoch: 15.62s, Remaining Time: 15min:6s
# Epoch: 443, Accuracy: 0.9906, Time: 15.16s, Avg. Time/Epoch: 15.62s, Remaining Time: 14min:50s
# Epoch: 444, Accuracy: 0.9892, Time: 15.15s, Avg. Time/Epoch: 15.62s, Remaining Time: 14min:35s
# Epoch: 445, Accuracy: 0.9873, Time: 15.16s, Avg. Time/Epoch: 15.62s, Remaining Time: 14min:19s
# Epoch: 446, Accuracy: 0.9914, Time: 15.17s, Avg. Time/Epoch: 15.62s, Remaining Time: 14min:3s
# Epoch: 447, Accuracy: 0.9903, Time: 15.16s, Avg. Time/Epoch: 15.62s, Remaining Time: 13min:48s
# Epoch: 448, Accuracy: 0.9894, Time: 15.15s, Avg. Time/Epoch: 15.62s, Remaining Time: 13min:32s
# Epoch: 449, Accuracy: 0.9904, Time: 15.16s, Avg. Time/Epoch: 15.62s, Remaining Time: 13min:16s
# Epoch: 450, Accuracy: 0.9923, Time: 15.16s, Avg. Time/Epoch: 15.62s, Remaining Time: 13min:1s
# Epoch: 451, Accuracy: 0.9908, Time: 15.16s, Avg. Time/Epoch: 15.61s, Remaining Time: 12min:45s
# Epoch: 452, Accuracy: 0.9907, Time: 15.16s, Avg. Time/Epoch: 15.61s, Remaining Time: 12min:29s
# Epoch: 453, Accuracy: 0.9925, Time: 15.14s, Avg. Time/Epoch: 15.61s, Remaining Time: 12min:14s
# Epoch: 454, Accuracy: 0.9917, Time: 15.15s, Avg. Time/Epoch: 15.61s, Remaining Time: 11min:58s
# Epoch: 455, Accuracy: 0.9922, Time: 15.15s, Avg. Time/Epoch: 15.61s, Remaining Time: 11min:42s
# Epoch: 456, Accuracy: 0.9916, Time: 15.16s, Avg. Time/Epoch: 15.61s, Remaining Time: 11min:27s
# Epoch: 457, Accuracy: 0.9925, Time: 15.15s, Avg. Time/Epoch: 15.61s, Remaining Time: 11min:11s
# Epoch: 458, Accuracy: 0.9926, Time: 15.15s, Avg. Time/Epoch: 15.61s, Remaining Time: 10min:55s
# Epoch: 459, Accuracy: 0.9840, Time: 15.13s, Avg. Time/Epoch: 15.61s, Remaining Time: 10min:40s
# Epoch: 460, Accuracy: 0.9925, Time: 15.14s, Avg. Time/Epoch: 15.61s, Remaining Time: 10min:24s
# Epoch: 461, Accuracy: 0.9925, Time: 15.15s, Avg. Time/Epoch: 15.60s, Remaining Time: 10min:9s
# Epoch: 462, Accuracy: 0.9888, Time: 15.16s, Avg. Time/Epoch: 15.60s, Remaining Time: 9min:53s
# Epoch: 463, Accuracy: 0.9924, Time: 15.15s, Avg. Time/Epoch: 15.60s, Remaining Time: 9min:37s
# Epoch: 464, Accuracy: 0.9906, Time: 15.16s, Avg. Time/Epoch: 15.60s, Remaining Time: 9min:22s
# Epoch: 465, Accuracy: 0.9909, Time: 15.16s, Avg. Time/Epoch: 15.60s, Remaining Time: 9min:6s
# Epoch: 466, Accuracy: 0.9910, Time: 15.17s, Avg. Time/Epoch: 15.60s, Remaining Time: 8min:50s
# Epoch: 467, Accuracy: 0.9921, Time: 15.18s, Avg. Time/Epoch: 15.60s, Remaining Time: 8min:35s
# Epoch: 468, Accuracy: 0.9914, Time: 15.16s, Avg. Time/Epoch: 15.60s, Remaining Time: 8min:19s
# Epoch: 469, Accuracy: 0.9914, Time: 15.14s, Avg. Time/Epoch: 15.60s, Remaining Time: 8min:3s
# Epoch: 470, Accuracy: 0.9923, Time: 15.16s, Avg. Time/Epoch: 15.60s, Remaining Time: 7min:48s
# Epoch: 471, Accuracy: 0.9919, Time: 15.14s, Avg. Time/Epoch: 15.59s, Remaining Time: 7min:32s
# Epoch: 472, Accuracy: 0.9912, Time: 15.15s, Avg. Time/Epoch: 15.59s, Remaining Time: 7min:17s
# Epoch: 473, Accuracy: 0.9928, Time: 15.15s, Avg. Time/Epoch: 15.59s, Remaining Time: 7min:1s
# Epoch: 474, Accuracy: 0.9878, Time: 15.16s, Avg. Time/Epoch: 15.59s, Remaining Time: 6min:45s
# Epoch: 475, Accuracy: 0.9929, Time: 15.14s, Avg. Time/Epoch: 15.59s, Remaining Time: 6min:30s
# Epoch: 476, Accuracy: 0.9920, Time: 15.13s, Avg. Time/Epoch: 15.59s, Remaining Time: 6min:14s
# Epoch: 477, Accuracy: 0.9914, Time: 15.13s, Avg. Time/Epoch: 15.59s, Remaining Time: 5min:59s
# Epoch: 478, Accuracy: 0.9905, Time: 15.15s, Avg. Time/Epoch: 15.59s, Remaining Time: 5min:43s
# Epoch: 479, Accuracy: 0.9919, Time: 15.14s, Avg. Time/Epoch: 15.59s, Remaining Time: 5min:27s
# Epoch: 480, Accuracy: 0.9913, Time: 15.16s, Avg. Time/Epoch: 15.59s, Remaining Time: 5min:12s
# Epoch: 481, Accuracy: 0.9927, Time: 15.15s, Avg. Time/Epoch: 15.59s, Remaining Time: 4min:56s
# Epoch: 482, Accuracy: 0.9919, Time: 15.16s, Avg. Time/Epoch: 15.58s, Remaining Time: 4min:41s
# Epoch: 483, Accuracy: 0.9927, Time: 15.15s, Avg. Time/Epoch: 15.58s, Remaining Time: 4min:25s
# Epoch: 484, Accuracy: 0.9927, Time: 15.13s, Avg. Time/Epoch: 15.58s, Remaining Time: 4min:9s
# Epoch: 485, Accuracy: 0.9928, Time: 15.14s, Avg. Time/Epoch: 15.58s, Remaining Time: 3min:54s
# Epoch: 486, Accuracy: 0.9917, Time: 15.16s, Avg. Time/Epoch: 15.58s, Remaining Time: 3min:38s
# Epoch: 487, Accuracy: 0.9895, Time: 15.13s, Avg. Time/Epoch: 15.58s, Remaining Time: 3min:23s
# Epoch: 488, Accuracy: 0.9913, Time: 15.15s, Avg. Time/Epoch: 15.58s, Remaining Time: 3min:7s
# Epoch: 489, Accuracy: 0.9924, Time: 15.16s, Avg. Time/Epoch: 15.58s, Remaining Time: 2min:51s
# Epoch: 490, Accuracy: 0.9908, Time: 15.16s, Avg. Time/Epoch: 15.58s, Remaining Time: 2min:36s
# Epoch: 491, Accuracy: 0.9920, Time: 15.14s, Avg. Time/Epoch: 15.58s, Remaining Time: 2min:20s
# Epoch: 492, Accuracy: 0.9900, Time: 15.15s, Avg. Time/Epoch: 15.58s, Remaining Time: 2min:5s
# Epoch: 493, Accuracy: 0.9908, Time: 15.14s, Avg. Time/Epoch: 15.57s, Remaining Time: 1min:49s
# Epoch: 494, Accuracy: 0.9886, Time: 15.15s, Avg. Time/Epoch: 15.57s, Remaining Time: 1min:33s
# Epoch: 495, Accuracy: 0.9927, Time: 15.14s, Avg. Time/Epoch: 15.57s, Remaining Time: 1min:18s
# Epoch: 496, Accuracy: 0.9871, Time: 15.16s, Avg. Time/Epoch: 15.57s, Remaining Time: 1min:2s
# Epoch: 497, Accuracy: 0.9914, Time: 15.15s, Avg. Time/Epoch: 15.57s, Remaining Time: 0min:47s
# Epoch: 498, Accuracy: 0.9906, Time: 15.16s, Avg. Time/Epoch: 15.57s, Remaining Time: 0min:31s
# Epoch: 499, Accuracy: 0.9913, Time: 15.13s, Avg. Time/Epoch: 15.57s, Remaining Time: 0min:16s
# Epoch: 500, Accuracy: 0.9917, Time: 15.14s, Avg. Time/Epoch: 15.57s, Remaining Time: 0min:0s
# Total Training Time: 0min:0s

# %%
fig, axs = plt.subplots(2, 2, constrained_layout=True, figsize=(10, 5))

axs[0][0].plot(np.arange(len(t_loss_v)), t_loss_v)
axs[0][0].set_title("Training loss")
axs[0][0].set_yscale("linear")

axs[0][1].plot(np.arange(len(t_acc_v)), t_acc_v)
axs[0][1].set_title("Training accuracy")
axs[0][1].set_yscale("linear")
axs[0][1].set_ylim(0, 1.05)

axs[1][0].plot(np.arange(len(v_loss_v)), v_loss_v)
axs[1][0].set_title("Validation loss")
axs[1][0].set_yscale("linear")

axs[1][1].plot(np.arange(len(v_acc_v)), v_acc_v)
axs[1][1].set_title("Validation accuracy")
axs[1][1].set_yscale("linear")
axs[1][1].set_ylim(0, 1.05)
# Out:
# <img src="data:image/png;base64,..." width="999.75">
# (0.0, 1.05)

# %%
# save trained model
# torch.save(model.state_dict(), './GNN_real_data_model.pth')

# %%
# load saved model
# model.load_state_dict(torch.load('./GNN_real_data_model.pth'))

# %%
def plot_2D_classified(event, preds, cut=0.5):

#     print(event)
#     print(event.x)
#     print(event.pid)
#     print(event.y)
#     print(preds)

    plt.figure(figsize=(10,5))
    
    x, y = event.x[:,0].numpy(), event.x[:,1].numpy()
    edges = event.edge_index.numpy()
    labels = event.y
    preds = preds.detach().numpy()
    
    plt.scatter(x, y, c='k')

    for j in range(len(labels)):

        s = str('%01.2f' % preds[j]) + '/' + str(labels[j].item())
        plt.text((x[edges[0, j]] + x[edges[1, j]]) / 2.,
                 (y[edges[0, j]] + y[edges[1, j]]) / 2.,
                 s, fontsize=8)

        # False negatives
        if preds[j] < cut and labels[j].item() > cut:
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '--', c='b')

        # False positives
        if preds[j] > cut and labels[j].item() < cut:
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '-', c='r', alpha=preds[j])

        # True positives
        if preds[j] > cut and labels[j].item() > cut:
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '-', c='k', alpha=0.3 + 0.5*preds[j])

        # True negatives
        if preds[j] < cut and labels[j].item() < cut:
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '--', c='k', alpha=0.3 + 0.5*preds[j])

# display few events            
for k in range(10):
    data = test_loader.dataset[k].to(device)
    preds = torch.sigmoid(model(data)).to('cpu')
    plot_2D_classified(data.to('cpu'), preds, cut = 0.5)
# Out:
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">
# <img src="data:image/png;base64,..." width="999.75">

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from sklearn.metrics import RocCurveDisplay, roc_curve
from sklearn.metrics import PrecisionRecallDisplay, precision_recall_curve

# this makes out of memory error
# y_test = torch.cat([data.y.cpu() for data in test_loader.dataset])
# y_score = torch.cat([torch.sigmoid(model(data.to(device))) for data in test_loader.dataset]).cpu()
# y_pred = y_score > 0.5

y_test = torch.cat([data.y.cpu() for data in test_loader.dataset])
y_pred = torch.cat([torch.sigmoid(model(data.to(device))) > 0.5 for data in test_loader.dataset]).cpu()

ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred)).plot()

# fpr, tpr, _ = roc_curve(y_test, y_score.detach().numpy())
# RocCurveDisplay(fpr=fpr, tpr=tpr).plot()

# prec, recall, _ = precision_recall_curve(y_test, y_score.detach().numpy())
# PrecisionRecallDisplay(precision=prec, recall=recall).plot()
# Out:
# <img src="data:image/png;base64,..." width="639.75">
